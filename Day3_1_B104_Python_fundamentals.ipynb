# %%
Introduction to List Daatype:
def:a list is a collection of items declared in a particular order
classification:It is classified as mutable
syntax:..[]

# %%
students=['vijay','swapna','david','varsha','madhavi']
print(students)
# Out:
# ['vijay', 'swapna', 'david', 'varsha', 'madhavi']

# %%
# How to access the the elements  in the above list:by use indexing
index start from 0,1,2...... in list

# %%
#Req: I want to access the vijay name from above list
print(students[0])# it should be displayed in Capital letters
# Out:
# vijay

# %%
print(students[0].title())
# Out:
# Vijay

# %%
#i want to access david name in output
print(students[2].title())
# Out:
# David

# %%
1 How to add new elements to the list
2 how to modify elements in the list
3 how to delete the elements from list

# %%
#I want to add 'udhay' name to list
students.append('udhay')

# %%
print(students)
# Out:
# ['vijay', 'swapna', 'david', 'varsha', 'madhavi', 'udhay', 'udhay']

# %%
#i want to add 'vihaan' to 6 th position
students.insert(6,'vihaan')

# %%
print(students)
# Out:
# ['vijay', 'swapna', 'david', 'varsha', 'madhavi', 'udhay', 'vihaan', 'udhay']

# %%
# interview question

what is the difference between append and insert in list data type

# %%
#how to modify the element in the list
Req:i want to  modify vijay names as vikas
inde
