# %%
fullname="vikas saini"

# %%
print(fullname)
# Out:
# vikas saini

# %%
print(fullname.title())
# Out:
# Vikas Saini

# %%
 3 i want entire name in  capital letters

# %%
print(fullname.upper())
# Out:
# VIKAS SAINI

# %%
# i want entire name in smallcase

# %%
print(fullname.lower())
# Out:
# vikas saini

# %%
Introduction to strings
message=f"custom message(place holder_1),(place_holder2),..........(place_holdern)"

# %%
firstname="kiran"
lastname="kumar"

# %%
#req:I want to get fullname

# %%
fullname=f"{firstname}{lastname}"
print(fullname)
# Out:
# kiranKumar

# %%
message=f"keep up the good work,{fullname.title()}"
print(message)
# Out:
# keep up the good work,Kirankumar

# %% [markdown]
# #adding  white spaces to strings
# req: I want to conduct a  conduct asurvey a group of students to choose for programming languages

# %%
print('fav_prog:PythonC++JavaDotnet')
# Out:
# fav_prog:PythonC++JavaDotnet

# %%
# \n new line delimeter
print('fav_prog:\nPython\nC++J\nJava\nDotnet')
# Out:
# fav_prog:
# Python
# C++J
# Java
# Dotnet

# %%
# \t tab delimeter
print('fav_prog:\n\tPython\n\tC++J\n\tJava\n\tDotnet')
# Out:
# fav_prog:
# 	Python
# 	C++J
# 	Java
# 	Dotnet

# %%
# removing white spaces from strings
name= "python"
print(name)
# Out:
# python

# %%
name2=" python"
print(name2)
# Out:
#  python

# %%
name3="python "
print(name3)
# Out:
# python

# %%
#how to eliminate space and striping
print(name2.lstrip())#left side stiping
# Out:
# python

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name.rstrip()
# Out:
# 'python'
