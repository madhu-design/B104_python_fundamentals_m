# %%
Interduction to python variables

# %%
Concept of variables

# %%
a=2
b=3
c=(a+b)
print(c)
# Out:
# 5

# %%
# Rules for declaring a variable in Python

# %%
Rule no 1:
No name spaces while declaring a varibles in python #

# %%
first name="madhavi"
print(first name)
# Out:
#   Cell In[4], line 1
#     first name="madhavi"
#           ^
# SyntaxError: invalid syntax

# %%
firstname="madhavi"
print(firstname)
# Out:
# madhavi

# %%
Rule no 2:
a variable name should not start with a number #

# %%
1name="madhu"
print(1name)
# Out:
#   Cell In[6], line 1
#     1name="madhu"
#     ^
# SyntaxError: invalid decimal literal

# %%
name1="madhu" #we can use numbers inbetween or end of the varibles
print(name1)
# Out:
# madhu

# %%
Rule no 3: A variable should not contain special chartecters like @,$,%,&,*

# %%
name@="Vihaan"
print?(name@)
# Out:
#   Cell In[9], line 2
#     print?(name@)
#          ^
# SyntaxError: invalid syntax

# %%
Data types in python

# %%
1   strings  str
2   numbers  integers(int),float
3   lists    list4
4   tuple    tuple
5   dictionaries  dict

# %%
Data types are classified into two different types
mutable 
immutable

# %%
mutable-------where we can edit the data

# %%
immutable------we cannot edit the date(fixed)

# %%
Introdution to string data type:

# %%
A string is nothing but a series of characters declared in quotes
classification: it is classified as an immutable datatype

# %%
how to declare a string--------single quote or double quote

# %%
name="rahul"
print(name)
# Out:
# rahul

# %%
name='rahul'
print(name)
# Out:
# rahul

# %%
Introduction to string methods
methods are built in programs
